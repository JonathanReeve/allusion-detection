# %%
import pandas as pd
# %matplotlib inline

# %%
data = [[1795, 'm', 0.33], [1802, 'm', 0.55], [1814, 'f', 0.66], [1920, 'm', 0.23]]

# %%
df = pd.DataFrame(data, columns=['years', 'gender', 'score'])
df = df.set_index('years')
df
# Out:
#       gender  score
# years
# 1795       m   0.33
# 1802       m   0.55
# 1814       f   0.66
# 1920       m   0.23

# %%
df['century'] = (df.index // 100) * 100
df
# Out:
#       gender  score  century
# years
# 1795       m   0.33     1700
# 1802       m   0.55     1800
# 1814       f   0.66     1800
# 1920       m   0.23     1900

# %%
#dg = df.groupby(['century']).mean()
dg = df.groupby(['gender'])
dg.plot()
# Out:
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1814.0, right=1814.0
#   'left=%s, right=%s') % (left, right))
# gender
# f    Axes(0.125,0.125;0.775x0.775)
# m    Axes(0.125,0.125;0.775x0.775)
# dtype: object

# %%
dg.plot()
# Out:
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1814.0, right=1814.0
#   'left=%s, right=%s') % (left, right))
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1795.0, right=1795.0
#   'left=%s, right=%s') % (left, right))
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1802.0, right=1802.0
#   'left=%s, right=%s') % (left, right))
# /usr/lib/python3.5/site-packages/matplotlib/axes/_base.py:2787: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1920.0, right=1920.0
# ...
